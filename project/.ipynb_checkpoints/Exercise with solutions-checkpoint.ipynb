# %% [markdown]
# # Data Exploration and PCA
# * The wine dataset contains the results of chemical analyses of wines grown in Italy from three different cultivars. The dataset includes several variables such as 'Alcohol', 'Malic Acid', 'Ash', etc., along with a 'Wine' column indicating the cultivar.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Step 1: Data Loading

# %%
wine_df = pd.read_csv('/Users/simona/Desktop/IRIB/Lezioni Data Science/2023/Lab06/wine.csv')

# %%
wine_df.head()
# Out:
#    Wine  Alcohol  Malic.acid   Ash   Acl   Mg  Phenols  Flavanoids  \
# 0     1    14.23        1.71  2.43  15.6  127     2.80        3.06
# 1     1    13.20        1.78  2.14  11.2  100     2.65        2.76
# 2     1    13.16        2.36  2.67  18.6  101     2.80        3.24
# 3     1    14.37        1.95  2.50  16.8  113     3.85        3.49
# 4     1    13.24        2.59  2.87  21.0  118     2.80        2.69
#
#    Nonflavanoid.phenols  Proanth  Color.int   Hue    OD  Proline
# 0                  0.28     2.29       5.64  1.04  3.92     1065
# 1                  0.26     1.28       4.38  1.05  3.40     1050
# 2                  0.30     2.81       5.68  1.03  3.17     1185
# 3                  0.24     2.18       7.80  0.86  3.45     1480
# 4                  0.39     1.82       4.32  1.04  2.93      735

# %%
wine_df.shape
# Out:
# (178, 14)

# %%
wine_df['Wine'].value_counts()
# Out:
# 2    71
# 1    59
# 3    48
# Name: Wine, dtype: int64

# %% [markdown]
# # Step 2: Data Cleaning

# %% [markdown]
# ## Check for missing values

# %%
wine_df.isnull().sum()
# Out:
# Wine                    0
# Alcohol                 0
# Malic.acid              0
# Ash                     0
# Acl                     0
# Mg                      0
# Phenols                 0
# Flavanoids              0
# Nonflavanoid.phenols    0
# Proanth                 0
# Color.int               0
# Hue                     0
# OD                      0
# Proline                 0
# dtype: int64

# %% [markdown]
# ## Check for duplicates

# %%
wine_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # Step 3: Data Exploration & EDA

# %% [markdown]
# ## Data types

# %%
wine_df.dtypes
# Out:
# Wine                      int64
# Alcohol                 float64
# Malic.acid              float64
# Ash                     float64
# Acl                     float64
# Mg                        int64
# Phenols                 float64
# Flavanoids              float64
# Nonflavanoid.phenols    float64
# Proanth                 float64
# Color.int               float64
# Hue                     float64
# OD                      float64
# Proline                   int64
# dtype: object

# %% [markdown]
# ## Statistical summary

# %%
wine_df.describe()
# Out:
#              Wine     Alcohol  Malic.acid         Ash         Acl          Mg  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#           Phenols  Flavanoids  Nonflavanoid.phenols     Proanth   Color.int  \
# count  178.000000  178.000000            178.000000  178.000000  178.000000
# mean     2.295112    2.029270              0.361854    1.590899    5.058090
# ...

# %% [markdown]
# ## Sample visualization: Histogram

# %%
wine_df.hist(bins=15,figsize=(12,8))
plt.title('Distribution of Alcohol in Wine Samples')
plt.show()

# %% [markdown]
# # Step 4: Data Processing - Standardizing the data

# %%
from sklearn.preprocessing import StandardScaler

# %%
X = wine_df.drop('Wine', axis=1)

# %%
# Standardizing the feature data
scaler_wine = StandardScaler()
X_scaled = scaler_wine.fit_transform(X)

# %% [markdown]
# # Step 5: PCA

# %% [markdown]
# ## Apply PCA using all the features

# %%
from sklearn.decomposition import PCA

# %%
pca_wine = PCA()
pca_features_wine = pca_wine.fit_transform(X_scaled)

# %%
# Variance explained by each principal component
explained_variance_wine = pca_wine.explained_variance_ratio_

# %%
labels = {
    str(i): f"PC {i+1} ({var:.1f}%)"
    for i, var in enumerate(explained_variance_wine * 100)
}
labels
# Out:
# {'0': 'PC 1 (36.2%)',
#  '1': 'PC 2 (19.2%)',
#  '2': 'PC 3 (11.1%)',
#  '3': 'PC 4 (7.1%)',
#  '4': 'PC 5 (6.6%)',
#  '5': 'PC 6 (4.9%)',
#  '6': 'PC 7 (4.2%)',
#  '7': 'PC 8 (2.7%)',
#  '8': 'PC 9 (2.2%)',
#  '9': 'PC 10 (1.9%)',
#  '10': 'PC 11 (1.7%)',
#  '11': 'PC 12 (1.3%)',
#  '12': 'PC 13 (0.8%)'}

# %% [markdown]
# ## Plot the first two principal components

# %%
plt.figure(figsize=(10, 8))
scatter_wine = plt.scatter(pca_features_wine[:, 0], pca_features_wine[:, 1], c=wine_df['Wine'], cmap='viridis')
plt.title('PCA of Wine Dataset - First two principal components')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend(*scatter_wine.legend_elements(), title="Wine Class")
plt.grid(True)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
scatter = ax.scatter(pca_features_wine[:, 0], pca_features_wine[:, 1], pca_features_wine[:, 2], c=wine_df['Wine'], cmap='viridis')
ax.set_title(f'PCA of Wine Dataset - First three principal components')
ax.set_xlabel('Principal Component 1')        
ax.set_ylabel('Principal Component 2')
ax.set_zlabel('Principal Component 3')
plt.legend(*scatter.legend_elements(), title="Wine Class")
plt.show()

# %%
# Create DataFrame with 5 PC components
df_pca = pd.DataFrame(PCA(n_components=5).fit_transform(X_scaled), columns=[f'PC{i+1}' for i in range(5)])
df_pca['Label'] = wine_df['Wine'].values

# Scatter Pairplot
sns.set_theme(style="ticks")
sns.pairplot(df_pca, hue="Label", diag_kind='hist', palette='Dark2')
plt.show()

# %% [markdown]
# ## Interpret the variance explained by the principal components and discuss the PCA plot.
